# %%
import sys
r = sys.stdin.readline
N = int(r())
A = list(map(int,r().split()))
dp = []
dp.append(A[0])
for i in A:
  if i > dp[-1]:
    dp.append(i)
  else:
    for j in range(len(dp)):
    	if dp[j] >= i:
    		dp[j] = i
    		break
print(len(dp))
